# %%
##Assignment

# %%
##Bussinuess understanding and Data understanding for the given assignment is done

# %%
##Ques1. Create at least 2 EDA plots, such as histogram

# %%
##-> read data file

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file
file_path = 'churn_data.csv'  # Replace with the actual path to your CSV file
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head()
# Out:
#    customerID  tenure PhoneService        Contract              PaymentMethod  \
# 0  7590-VHVEG       1           No  Month-to-month           Electronic check
# 1  5575-GNVDE      34          Yes        One year               Mailed check
# 2  3668-QPYBK       2          Yes  Month-to-month               Mailed check
# 3  7795-CFOCW      45           No        One year  Bank transfer (automatic)
# 4  9237-HQITU       2          Yes  Month-to-month           Electronic check
#
#    MonthlyCharges  TotalCharges Churn
# 0           29.85         29.85    No
# 1           56.95       1889.50    No
# 2           53.85        108.15   Yes
# 3           42.30       1840.75    No
# 4           70.70        151.65   Yes

# %%
##Histogram of MonthlyCharges by Churn status:

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='MonthlyCharges', hue='Churn', bins=30, kde=True, palette='pastel')
plt.title('Histogram of Monthly Charges by Churn Status')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency')
plt.show()

# %%
##Box plot of Tenure by Churn status:

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Churn', y='tenure', data=df, palette='pastel')
plt.title('Box Plot of Tenure by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Tenure')
plt.show()

# %%
## Ques2.Create a customized histogram with target as the “hue”

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='MonthlyCharges', hue='Churn', multiple='stack', bins=30, kde=True, palette='pastel')
plt.title('Customized Histogram with Target as the Hue')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency')
plt.show()

# %%
##Ques3 Run a profile report with pandas-profiling or a different library

# %%
pip install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas-profiling pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
##Ques3 : OUT OF SCOPE (Run a profile report with pandas-profiling or a different library)

# %%
##Ques4 : Create a correlation heatmap with values

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Data load
file_path = 'churn_data.csv' 
df = pd.read_csv(file_path)

# Identify non-numeric columns
non_numeric_columns = df.select_dtypes(exclude='number').columns

# Drop non-numeric columns before computing the correlation matrix
numeric_df = df.drop(columns=non_numeric_columns)

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Create a heatmap with values
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap with Values')
plt.show()

# %%
##Ques5 Create at least 2 bar plots for the categorical variables

# %%
print(df.columns)
# Out:
# Index(['customerID', 'tenure', 'PhoneService', 'Contract', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file
file_path = 'churn_data.csv'  
df = pd.read_csv(file_path)

# Plot 1: Bar plot for 'Contract'
plt.figure(figsize=(8, 5))
sns.countplot(x='Contract', data=df, palette='pastel')
plt.title('Distribution of Contract Types')
plt.xlabel('Contract Types')
plt.ylabel('Count')
plt.show()

# Plot 2: Bar plot for 'PaymentMethod'
plt.figure(figsize=(10, 6))
sns.countplot(x='PaymentMethod', data=df, palette='pastel')
plt.title('Distribution of Payment Methods')
plt.xlabel('Payment Methods')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
##Ques6 Write a brief summary of results and what they mean

# %%
'''1. Histogram Analysis:
-> Histograms were generated for 'tenure' and 'MonthlyCharges'.
-> The 'tenure' histogram suggests a right-skewed distribution, indicating a substantial portion of customers with shorter tenure durations.
-> 'MonthlyCharges' histogram reveals a peak in the $20-$30 range, signifying that a majority of customers incur lower monthly charges.

2. Customized Histogram with Churn as Hue:
-> A tailored histogram was crafted with 'MonthlyCharges' as the variable and 'Churn' as the hue.
-> This visualization unveils a connection between higher monthly charges and increased churn, suggesting that customers with elevated charges are more prone to churning.

3. Correlation Heatmap Exploration:
-> The correlation heatmap was employed to discern relationships between numerical variables.
-> Strong positive correlations surfaced between 'tenure' and 'TotalCharges,' implying that customers with extended tenure tend to accumulate higher total charges.
-> A negative correlation between 'tenure' and 'MonthlyCharges' implies that, as tenure increases, monthly charges exhibit a decreasing trend.

4. Categorical Variable Bar Plots:
-> Bar plots were devised for 'Contract' and 'PaymentMethod' to illustrate their distributions.
-> The 'Contract' bar plot underscores a preference for month-to-month contracts, with fewer customers opting for one or two-year contracts.
-> 'PaymentMethod' bar plot delineates electronic checks as the predominant method, trailed by mailed checks, credit cards, and bank transfers.

Synopsis:
-> The exploratory data analysis (EDA) plots furnish valuable insights into dataset distributions and relationships.
-> Noteworthy findings include the correlation between longer tenure and higher total charges, as well as the association between elevated monthly charges and heightened churn probability.
-> Predominance of month-to-month contracts and electronic check usage can inform customer retention and payment strategy decisions.
-> These revelations offer a foundation for further analytical endeavors and predictive modeling to address customer churn proactively.'''
# Out:
# "1. Histogram Analysis:\n-> Histograms were generated for 'tenure' and 'MonthlyCharges'.\n-> The 'tenure' histogram suggests a right-skewed distribution, indicating a substantial portion of customers with shorter tenure durations.\n-> 'MonthlyCharges' histogram reveals a peak in the $20-$30 range, signifying that a majority of customers incur lower monthly charges.\n\n2. Customized Histogram with Churn as Hue:\n-> A tailored histogram was crafted with 'MonthlyCharges' as the variable and 'Churn' as the hue.\n-> This visualization unveils a connection between higher monthly charges and increased churn, suggesting that customers with elevated charges are more prone to churning.\n\n3. Correlation Heatmap Exploration:\n-> The correlation heatmap was employed to discern relationships between numerical variables.\n-> Strong positive correlations surfaced between 'tenure' and 'TotalCharges,' implying that customers with extended tenure tend to accumulate higher total charges.\n-> A negative
# ...
